# %% [markdown]
# <a href="https://colab.research.google.com/github/srikanthkutty777-hash/Face-Mask-Detection/blob/main/Face_Mask_Detection_YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics opencv-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 30.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 3.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8n.pt")

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-e312f2a8-5d86-4890-8713-e143c2416abd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e312f2a8-5d86-4890-8713-e143c2416abd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
results = model.predict(
    source="images.jpg",
    save=True
)
# Out:
# image 1/1 /content/images.jpg: 416x640 11 persons, 320.9ms
# Speed: 14.6ms preprocess, 320.9ms inference, 37.3ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to /content/runs/detect/predict

# %%
from PIL import Image

Image.open(results[0].save_dir + "/" + "images.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=698x439>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-4321548f-001b-4a79-8d03-a7504d41c828" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4321548f-001b-4a79-8d03-a7504d41c828">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e634726c-0ba6-49a7-884b-233842abfb3f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e634726c-0ba6-49a7-884b-233842abfb3f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-15c9076c-016e-4c16-8fef-47975622d7a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15c9076c-016e-4c16-8fef-47975622d7a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

model = YOLO("best.pt")

# %%
results = model.predict(
    source="images (1).jpg",   # replace with your uploaded image name
    save=True,
    conf=0.4
)
# Out:
# image 1/1 /content/images (1).jpg: 416x640 8 without_masks, 5 with_masks, 1 mask_weared_incorrect, 379.9ms
# Speed: 15.4ms preprocess, 379.9ms inference, 35.2ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to /content/runs/detect/predict

# %%
from PIL import Image
import os

output = os.path.join(
    results[0].save_dir,
    os.path.basename(results[0].path)
)

Image.open(output)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=660x426>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-186d8771-07a8-442a-bcd9-46690882735b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-186d8771-07a8-442a-bcd9-46690882735b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
results = model.predict(
    source="1-s2.0-S1319157821003633-gr3.jpg",
    save=True,
    conf=0.4
)
# Out:
# image 1/1 /content/1-s2.0-S1319157821003633-gr3.jpg: 416x640 14 without_masks, 14 with_masks, 139.9ms
# Speed: 4.6ms preprocess, 139.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to /content/runs/detect/predict-2

# %%
from PIL import Image
import os

output = os.path.join(
    results[0].save_dir,
    os.path.basename(results[0].path)
)

Image.open(output)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=533x342>
