# %% [markdown]
# <a href="https://colab.research.google.com/github/srikanthkutty777-hash/Face-Mask-Detection/blob/main/Face_Mask_Detection_YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics opencv-python

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d964d653-b783-4907-9917-1fc8a0ea457d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d964d653-b783-4907-9917-1fc8a0ea457d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

model = YOLO("best.pt")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e9a1d924-138d-452f-a906-d3919683678c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9a1d924-138d-452f-a906-d3919683678c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filename = list(uploaded.keys())[0]

results = model.predict(
    source=filename,
    save=True,
    conf=0.4
)
# Out:
# image 1/1 /content/images (2) (2).jpg: 448x640 5 with_masks, 454.2ms
# Speed: 19.2ms preprocess, 454.2ms inference, 39.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict

# %%
from PIL import Image
import os

output = os.path.join(results[0].save_dir, os.path.basename(results[0].path))
Image.open(output)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=547x365>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8b340d37-f101-4f73-a120-612923690243" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b340d37-f101-4f73-a120-612923690243">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filename = list(uploaded.keys())[0]

results = model.predict(
    source=filename,
    save=True,
    conf=0.4
)
# Out:
# image 1/1 /content/394d52daf13f9ba7f0773615aadc87b730590bf05e74a98d9df497175038e8fa.jpg: 448x640 7 without_masks, 8 with_masks, 160.4ms
# Speed: 4.4ms preprocess, 160.4ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict

# %%
from PIL import Image
import os

output = os.path.join(results[0].save_dir, os.path.basename(results[0].path))
Image.open(output)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1140x760>
